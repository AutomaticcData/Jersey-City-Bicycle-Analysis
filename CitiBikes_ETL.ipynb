# %%
#dependencies
# %matplotlib notebook

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

from datetime import datetime, date

def calculate_age(born):
    today = date.today()
    return today.year - born.year - ((today.month, today.day) < (born.month, born.day))

# %%
#create a listing of objects in the data directory
this_dir = os.listdir("data")

#store the number of datasets found to compare later
#len(this_dir)
numfiles = len(this_dir)

# %%
#setup a counter
row = 0

for i in this_dir:
    row += 1
    #file_name = i.replace(".csv","")
    #print(i)

# %%
file01_path = "data/JC-201509-citibike-tripdata.csv"
file02_path = "data/JC-201510-citibike-tripdata.csv"
file03_path = "data/JC-201511-citibike-tripdata.csv"
file04_path = "data/JC-201512-citibike-tripdata.csv"
file05_path = "data/JC-201601-citibike-tripdata.csv"
file06_path = "data/JC-201602-citibike-tripdata.csv"
file07_path = "data/JC-201603-citibike-tripdata.csv"
file08_path = "data/JC-201604-citibike-tripdata.csv"
file09_path = "data/JC-201605-citibike-tripdata.csv"
file010_path = "data/JC-201606-citibike-tripdata.csv"
file011_path = "data/JC-201607-citibike-tripdata.csv"
file012_path = "data/JC-201608-citibike-tripdata.csv"
file013_path = "data/JC-201609-citibike-tripdata.csv"
file014_path = "data/JC-201610-citibike-tripdata.csv"
file015_path = "data/JC-201611-citibike-tripdata.csv"
file016_path = "data/JC-201612-citibike-tripdata.csv"
file017_path = "data/JC-201701-citibike-tripdata.csv"
file018_path = "data/JC-201702-citibike-tripdata.csv"
file019_path = "data/JC-201703-citibike-tripdata.csv"
file020_path = "data/JC-201704-citibike-tripdata.csv"
file021_path = "data/JC-201705-citibike-tripdata.csv"
file022_path = "data/JC-201706-citibike-tripdata.csv"
file023_path = "data/JC-201707-citibike-tripdata.csv"
file024_path = "data/JC-201708 citibike-tripdata.csv"
file025_path = "data/JC-201709-citibike-tripdata.csv"
file026_path = "data/JC-201710-citibike-tripdata.csv"
file027_path = "data/JC-201711-citibike-tripdata.csv"
file028_path = "data/JC-201712-citibike-tripdata.csv"
file029_path = "data/JC-201801-citibike-tripdata.csv"
file030_path = "data/JC-201802-citibike-tripdata.csv"
file031_path = "data/JC-201803-citibike-tripdata.csv"
file032_path = "data/JC-201804-citibike-tripdata.csv"
file033_path = "data/JC-201805-citibike-tripdata.csv"
file034_path = "data/JC-201806-citibike-tripdata.csv"
file035_path = "data/JC-201807-citibike-tripdata.csv"
file036_path = "data/JC-201808-citibike-tripdata.csv"
file037_path = "data/JC-201809-citibike-tripdata.csv"
file038_path = "data/JC-201810-citibike-tripdata.csv"
file039_path = "data/JC-201811-citibike-tripdata.csv"

# %%
file01_df = pd.read_csv(file01_path)
file02_df = pd.read_csv(file02_path)
file03_df = pd.read_csv(file03_path)
file04_df = pd.read_csv(file04_path)
file05_df = pd.read_csv(file05_path)
file06_df = pd.read_csv(file06_path)
file07_df = pd.read_csv(file07_path)
file08_df = pd.read_csv(file08_path)
file09_df = pd.read_csv(file09_path)
file010_df = pd.read_csv(file010_path)
file011_df = pd.read_csv(file011_path)
file012_df = pd.read_csv(file012_path)
file013_df = pd.read_csv(file013_path)
file014_df = pd.read_csv(file014_path)
file015_df = pd.read_csv(file015_path)
file016_df = pd.read_csv(file016_path)
file017_df = pd.read_csv(file017_path)
file018_df = pd.read_csv(file018_path)
file019_df = pd.read_csv(file019_path)
file020_df = pd.read_csv(file020_path)
file021_df = pd.read_csv(file021_path)
file022_df = pd.read_csv(file022_path)
file023_df = pd.read_csv(file023_path)
file024_df = pd.read_csv(file024_path)
file025_df = pd.read_csv(file025_path)
file026_df = pd.read_csv(file026_path)
file027_df = pd.read_csv(file027_path)
file028_df = pd.read_csv(file028_path)
file029_df = pd.read_csv(file029_path)
file030_df = pd.read_csv(file030_path)
file031_df = pd.read_csv(file031_path)
file032_df = pd.read_csv(file032_path)
file033_df = pd.read_csv(file033_path)
file034_df = pd.read_csv(file034_path)
file035_df = pd.read_csv(file035_path)
file036_df = pd.read_csv(file036_path)
file037_df = pd.read_csv(file037_path)
file038_df = pd.read_csv(file038_path)
file039_df = pd.read_csv(file039_path)

# %%
file01_df.head(2)
# Out:
#    Trip Duration           Start Time            Stop Time  Start Station ID  \
# 0             61  2015-09-21 14:53:16  2015-09-21 14:54:17              3185
# 1            290  2015-09-21 14:55:59  2015-09-21 15:00:50              3183
#
#   Start Station Name  Start Station Latitude  Start Station Longitude  \
# 0          City Hall               40.717733               -74.043845
# 1     Exchange Place               40.716247               -74.033459
#
#    End Station ID End Station Name  End Station Latitude  \
# 0            3185        City Hall             40.717733
# 1            3187        Warren St             40.721124
#
#    End Station Longitude  Bike ID   User Type  Birth Year  Gender
# 0             -74.043845    24722  Subscriber      1975.0       1
# 1             -74.038051    24388    Customer         NaN       0

# %%
file02_df.head(2)

# %%
bigdata = pd.concat([file01_df, file02_df, file03_df, file04_df, file05_df, file06_df, 
file07_df, file08_df, file09_df, file010_df, file011_df, file012_df, file013_df, file014_df, 
file015_df, file016_df, file017_df, file018_df, file019_df, file020_df, file021_df, file022_df, 
file023_df, file024_df, file025_df, file026_df, file027_df, file028_df, file029_df, file030_df, 
file031_df, file032_df, file033_df, file034_df, file035_df, file036_df, file037_df, file038_df, file039_df], ignore_index=True, sort=True)

# %%
bigdata.count()
# Out:
# Bike ID                    339620
# Birth Year                 313288
# End Station ID             339620
# End Station Latitude       339620
# End Station Longitude      339620
# End Station Name           339620
# Gender                     339620
# Start Station ID           339620
# Start Station Latitude     339620
# Start Station Longitude    339620
# Start Station Name         339620
# Start Time                 339620
# Stop Time                  339620
# Trip Duration              339620
# User Type                  339123
# bikeid                     589462
# birth year                 571552
# end station id             589462
# end station latitude       589462
# end station longitude      589462
# end station name           589462
# gender                     589462
# start station id           589462
# start station latitude     589462
# start station longitude    589462
# start station name         589462
# starttime                  589462
# ...

# %%
#DESCRIPTION OF THE DATA - not needed at this time
#bigdata.describe()

# %%
bigdata.head()
# Out:
#    Bike ID  Birth Year  End Station ID  End Station Latitude  \
# 0  24722.0      1975.0          3185.0             40.717733
# 1  24388.0         NaN          3187.0             40.721124
# 2  24442.0      1962.0          3183.0             40.716247
# 3  24678.0      1977.0          3203.0             40.727596
# 4  24574.0      1977.0          3186.0             40.719586
#
#    End Station Longitude End Station Name  Gender  Start Station ID  \
# 0             -74.043845        City Hall     1.0            3185.0
# 1             -74.038051        Warren St     0.0            3183.0
# 2             -74.033459   Exchange Place     1.0            3183.0
# 3             -74.044247    Hamilton Park     2.0            3203.0
# 4             -74.043117    Grove St PATH     2.0            3203.0
#
#    Start Station Latitude  Start Station Longitude    ...    end station name  \
# 0               40.717733               -74.043845    ...                 NaN
# ...

# %%
bigdata_output = "data/NYC_BikeData_2018.csv"

print(len(bigdata))
print(len(bigdata.columns))
# Out:
# 929082
# 30

# %%
##file operations
bigdata.to_csv(bigdata_output)

# %%
#DO EXTERNAL ETL
#2 sets of data became offset due to naming conventions that were later changed
#causing the data to show in 30 columns instead of 15. External file manipulation using excel
#took place here

# %%
fileJCBikes_path = "data/NYC_BikeData_2018.csv"
fileJCBikes_df = pd.read_csv(fileJCBikes_path)
fileJCBikes_df.head()
# Out:
#    Bike ID  Birth Year  End Station ID  End Station Latitude  \
# 0    24722      1975.0            3185             40.717733
# 1    24388         NaN            3187             40.721124
# 2    24442      1962.0            3183             40.716247
# 3    24678      1977.0            3203             40.727596
# 4    24574      1977.0            3186             40.719586
#
#    End Station Longitude End Station Name  Gender  Start Station ID  \
# 0             -74.043845        City Hall       1              3185
# 1             -74.038051        Warren St       0              3183
# 2             -74.033459   Exchange Place       1              3183
# 3             -74.044247    Hamilton Park       2              3203
# 4             -74.043117    Grove St PATH       2              3203
#
#    Start Station Latitude  Start Station Longitude Start Station Name  \
# 0               40.717733               -74.043845          City Hall
# ...

# %%
fileJCBikes_df.describe()
# Out:
#              Bike ID     Birth Year  End Station ID  End Station Latitude  \
# count  929082.000000  884840.000000   929082.000000         929082.000000
# mean    27623.504467    1979.847500     3227.393609             40.687894
# std      2878.403304      10.043874      112.078094              1.183220
# min     14529.000000    1887.000000       79.000000              0.000000
# 25%     24676.000000    1974.000000     3186.000000             40.716540
# 50%     26290.000000    1982.000000     3202.000000             40.719586
# 75%     29569.000000    1987.000000     3214.000000             40.727224
# max     35009.000000    2002.000000     3694.000000             40.814326
#
#        End Station Longitude         Gender  Start Station ID  \
# count          929082.000000  929082.000000      929082.00000
# mean              -73.982998       1.136324        3232.04146
# std                 2.151439       0.512329          94.30488
# ...

# %%
fileJCBikes_df.count()
# Out:
# Bike ID                    929082
# Birth Year                 884840
# End Station ID             929082
# End Station Latitude       929082
# End Station Longitude      929082
# End Station Name           929082
# Gender                     929082
# Start Station ID           929082
# Start Station Latitude     929082
# Start Station Longitude    929082
# Start Station Name         929082
# Start Time                 929082
# Stop Time                  929082
# Trip Duration              929082
# User Type                  928585
# dtype: int64

# %%
#ad_counts_byage = pd.DataFrame(fileJCBikes_df.groupby("Age Range")["SN"].count())

# %%
pfix = [ value for value in fileJCBikes_df["Birth Year"]]
#pfix

# %%
current_year = int(datetime.now().year)
print(current_year)
# Out:
# 2018

# %%
min(fileJCBikes_df["Birth Year"])
# Out:
# 1887.0

# %%
max(fileJCBikes_df["Birth Year"])
# Out:
# 2002.0

# %%
min(fileJCBikes_df["Start Time"])
# Out:
# '00:00.0'

# %%
max(fileJCBikes_df["Stop Time"])
# Out:
# '9/9/2017 9:59'

# %%
#external ETL process due to non existent/invalid time stamps 
JCBikes_path = "data/JC_BikeData_Filtered_2018.csv"
JCBikes_df = pd.read_csv(JCBikes_path)
JCBikes_df.head()
# Out:
#    Bike ID  Birth Year  End Station ID  End Station Latitude  \
# 0    24722      1975.0            3185             40.717733
# 1    24388         NaN            3187             40.721124
# 2    24442      1962.0            3183             40.716247
# 3    24678      1977.0            3203             40.727596
# 4    24574      1977.0            3186             40.719586
#
#    End Station Longitude End Station Name  Gender  Start Station ID  \
# 0             -74.043845        City Hall       1              3185
# 1             -74.038051        Warren St       0              3183
# 2             -74.033459   Exchange Place       1              3183
# 3             -74.044247    Hamilton Park       2              3203
# 4             -74.043117    Grove St PATH       2              3203
#
#    Start Station Latitude  Start Station Longitude Start Station Name  \
# 0               40.717733               -74.043845          City Hall
# ...

# %%
JCBikes_df.count()
# Out:
# Bike ID                    595395
# Birth Year                 551153
# End Station ID             595395
# End Station Latitude       595395
# End Station Longitude      595395
# End Station Name           595395
# Gender                     595395
# Start Station ID           595395
# Start Station Latitude     595395
# Start Station Longitude    595395
# Start Station Name         595395
# Start Time                 595395
# Stop Time                  595395
# Trip Duration              595395
# User Type                  594898
# dtype: int64

# %%
JCBikes_df.describe()
# Out:
#              Bike ID     Birth Year  End Station ID  End Station Latitude  \
# count  595395.000000  551153.000000   595395.000000         595395.000000
# mean    26566.636295    1979.556502     3210.239142             40.668603
# std      2475.948857       9.889209       81.086623              1.477693
# min     14529.000000    1887.000000       79.000000              0.000000
# 25%     24571.000000    1975.000000     3186.000000             40.716540
# 50%     26181.000000    1982.000000     3199.000000             40.719586
# 75%     29253.000000    1987.000000     3213.000000             40.727224
# max     33463.000000    2001.000000     3640.000000             40.804213
#
#        End Station Longitude         Gender  Start Station ID  \
# count          595395.000000  595395.000000     595395.000000
# mean              -73.947992       1.128206       3213.791496
# std                 2.686885       0.517789         47.566071
# ...

# %%
min(JCBikes_df["Start Time"])
# Out:
# '1/1/2016 0:02'

# %%
max(JCBikes_df["Start Time"])
# Out:
# '9/9/2017 9:59'

# %%
max(JCBikes_df["Stop Time"])
# Out:
# '9/9/2017 9:59'
